# %% [markdown]
# Data Pipelines with Python Project-simeon omeda
# ---

# %% [markdown]
# #Project Deliverable
# Telecom companies often have to extract billing data from multiple CSV files generated from
# various systems and transform it into a structured format for analysis and revenue reporting.
# This process can be time-consuming, error-prone, and hinder decision-making. Manually
# analyzing and reconciling billing data from different sources is a tedious task and often leads to
# delays in generating revenue reports. Thus, there is a need for an automated data pipeline that
# can extract billing data from multiple sources and transform it into a structured format for
# efficient analysis and revenue reporting.
# # Guidelines
# Here are some guidelines and hints to help you create the data pipeline:
# ● Determine the requirements: First, you need to define the requirements of the data
# pipeline, including the source and destination of the data, the type of data that needs to
# be processed, the transformations that need to be applied, and the output format.
# ● Extract the data: Use Python to read the CSV files and extract the data.
# ● Clean the data: Perform data cleaning on the extracted data to remove any missing
# values and outliers. For example, you can replace missing values with an appropriate
# value or remove them altogether.
# ● Transform the data: Apply any necessary transformations on the data, such as data
# type conversion, data aggregation, and data filtering, to prepare the data for analysis.
# ● Merge the datasets: Join the different datasets into a single dataset that can be used for
# analysis.
# ● Load the data: Load the transformed data into a database or a file, such as a CSV file,
# that can be easily analyzed.
# ● Automate the process: Automate the data pipeline by scheduling it to run at a specific
# time, such as daily or weekly so that it can update the analysis data automatically.
# ● Test the pipeline: Test the data pipeline to ensure it produces the correct results. This
# can be done by comparing the results with the expected output or using a test dataset.
# ● Optimize the pipeline: Optimize the data pipeline to improve performance and reduce
# errors. This can be done by optimizing the code, parallel processing, and reducing the
# data size.
# ● Monitor the pipeline: Monitor the data pipeline to ensure that it runs smoothly and that
# there are no errors or issues.
# #Datasets
# Here are three sample datasets (https://bit.ly/416WE1X) with billing data that can be joined. The
# datasets contain some missing values and outliers:
# Dataset 1:
# ● Customer ID (numeric)
# ● Date of purchase (MM/DD/YYYY)
# ● Total amount billed (numeric)
# ● Payment status (categorical - paid, overdue, disputed)
# ● Payment method (categorical - credit card, bank transfer, e-wallet)
# ● Promo code (text)
# ● Country of purchase (categorical)
# Dataset 2:
# ● Customer ID (numeric)
# ● Date of payment (MM/DD/YYYY)
# ● Amount paid (numeric)
# ● Payment method (categorical - credit card, bank transfer, e-wallet)
# ● Payment status (categorical - paid, overdue, disputed)
# ● Late payment fee (numeric)
# ● Country of payment (categorical)
# Dataset 3:
# ● Customer ID (numeric)
# ● Date of refund (MM/DD/YYYY)
# ● Refund amount (numeric)
# ● Reason for refund (text)
# ● Country of refund (categorical)
# Notes:
# 1. The datasets can be joined using Customer ID, Date of purchase/payment/refund, and
# country of purchase/payment/refund as keys.
# 2. The datasets may contain missing values and outliers for some fields, such as the total
# amount billed or refund amount.
# 3. The payment status may be missing or incomplete for some of the transactions.
# 4. The promo code field may be empty for some of the purchases.
# 5. The reason for the refund may be missing for some of the refund transactions.

# %% [markdown]
# **Extract the data**: Use Python to read the CSV files and extract the data.

# %%
import pandas as pd
import os

# %%
# Load the datasets
df1 = pd.read_csv('dataset1.csv')
df2 = pd.read_csv('dataset2.csv')
df3 = pd.read_csv('dataset3.csv')

# %%
df1.head()
# Out:
#    customer_id date_of_purchase  total_amount_billed payment_status  \
# 0          101       04/01/2021                  100           paid
# 1          102       04/02/2021                  200           paid
# 2          103       04/02/2021                   50        overdue
# 3          104       04/03/2021                   75       disputed
# 4          105       04/04/2021                  125           paid
#
#   payment_method promo_code country_of_purchase
# 0    credit card     PROMO1                 USA
# 1  bank transfer     PROMO2                 USA
# 2    credit card        NaN                  UK
# 3       e-wallet     PROMO3                  UK
# 4    credit card     PROMO4                 USA

# %%
df2.head()

# %%
df3.head()

# %% [markdown]
# **Clean the data:** Perform data cleaning on the extracted data to remove any missing
# values and outliers. For example, you can replace missing values with an appropriate
# value or remove them altogether.

# %%
df1.isnull().sum()
# Out:
# customer_id            0
# date_of_purchase       0
# total_amount_billed    0
# payment_status         0
# payment_method         0
# promo_code             3
# country_of_purchase    0
# dtype: int64

# %%
df1= df1.dropna()

# %%
df1.isnull().sum()
# Out:
# customer_id            0
# date_of_purchase       0
# total_amount_billed    0
# payment_status         0
# payment_method         0
# promo_code             0
# country_of_purchase    0
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# customer_id          0
# date_of_refund       0
# refund_amount        0
# reason_for_refund    0
# country_of_refund    0
# dtype: int64

# %% [markdown]
# Transform the data: Apply any necessary transformations on the data, such as data
# type conversion, data aggregation, and data filtering, to prepare the data for analysis.
# ● Merge the datasets: Join the different datasets into a single dataset that can be used for
# analysis.

# %%
df_merged = df1.merge(df2,on = "customer_id").merge(df3, on="customer_id" )
df_merged
# Out:
#     customer_id date_of_purchase  total_amount_billed payment_status_x  \
# 0           101       04/01/2021                  100             paid
# 1           102       04/02/2021                  200             paid
# 2           104       04/03/2021                   75         disputed
# 3           105       04/04/2021                  125             paid
# 4           107       04/06/2021                   75          overdue
# 5           108       04/06/2021                  100          overdue
# 6           110       04/07/2021                   25          overdue
# 7           111       04/08/2021                  175             paid
# 8           112       04/08/2021                  200             paid
# 9           113       04/09/2021                   50         disputed
# 10          114       04/10/2021                  100             paid
# 11          115       04/10/2021                   75          overdue
#
#    payment_method_x promo_code country_of_purchase date_of_payment  \
# 0       credit card     PROMO1                 USA      04/01/2021
# 1     bank transfer     PROMO2                 USA      04/03/2021
# 2          e-wallet     PROMO3                  UK      04/04/2021
# 3       credit card     PROMO4                 USA      04/05/2021
# 4          e-wallet     PROMO5                 USA      04/07/2021
# 5     bank transfer     PROMO6                 USA      04/07/2021
# 6       credit card     PROMO7                 USA      04/08/2021
# 7          e-wallet     PROMO8                  UK      04/09/2021
# 8     bank transfer     PROMO9                 USA      04/10/2021
# 9       credit card    PROMO10                 USA      04/10/2021
# 10      credit card    PROMO11                 USA      04/11/2021
# 11         e-wallet    PROMO12                  UK      04/12/2021
#
#     amount_paid payment_method_y payment_status_y  late_payment_fee  \
# 0           100      credit card             paid                 0
# 1           200    bank transfer             paid                 0
# 2            50         e-wallet          overdue                 0
# 3           125      credit card             paid                 0
# 4            75         e-wallet          overdue                20
# 5           100    bank transfer          overdue                30
# 6            25      credit card             paid                 0
# 7           175         e-wallet             paid                 0
# 8           200    bank transfer             paid                 0
# 9            50      credit card         disputed                 0
# 10          100      credit card             paid                 0
# 11           75         e-wallet          overdue                15
#
#    country_of_payment date_of_refund  refund_amount         reason_for_refund  \
# 0                 USA     04/03/2021            100  product not as described
# 1                 USA     04/06/2021            200         defective product
# 2                  UK     04/08/2021             50      product not received
# 3                 USA     04/09/2021             25  product not as described
# 4                 USA     04/12/2021            150            change of mind
# 5                 USA     04/13/2021             75  product not as described
# 6                 USA     04/14/2021             50      product not received
# 7                  UK     04/15/2021            175         defective product
# 8                 USA     04/16/2021            200            change of mind
# 9                 USA     04/16/2021             50  product not as described
# 10                USA     04/17/2021            100         defective product
# 11                 UK     04/18/2021             75      product not received
#
#    country_of_refund
# 0                USA
# 1                USA
# 2                 UK
# 3                USA
# 4                USA
# 5                USA
# 6                USA
# 7                 UK
# 8                USA
# 9                USA
# 10               USA
# 11                UK

# %% [markdown]
# ● Load the data: Load the transformed data into a database or a file, such as a CSV file,
# that can be easily analyzed.

# %%
df_merged.to_csv("merged.csv", index=False)

# %% [markdown]
# Automate the process: Automate the data pipeline by scheduling it to run at a specific
# time, such as daily or weekly so that it can update the analysis data automatically.

# %%
import os.path
from os import path
from datetime import datetime, timedelta
from airflow import DAG
from airflow.operators.python_operator import PythonOperator
import pandas as pd
import psycopg2
# Out:
# <ipython-input-13-3a18194e96a4>:5 DeprecationWarning: The `airflow.operators.python_operator.PythonOperator` class is deprecated. Please use `'airflow.operators.python.PythonOperator'`.

# %%
pip install apache-airflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting apache-airflow
#   Downloading apache_airflow-2.5.2-py3-none-any.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 92.9 MB/s eta 0:00:00
# Collecting mdit-py-plugins>=0.3.0
#   Downloading mdit_py_plugins-0.3.5-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 KB 6.5 MB/s eta 0:00:00
# Collecting flask-login>=0.6.2
#   Downloading Flask_Login-0.6.2-py3-none-any.whl (17 kB)
# Collecting flask-session>=0.4.0
#   Downloading Flask_Session-0.4.0-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: tenacity!=8.2.0,>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from apache-airflow) (8.2.2)
# Requirement already satisfied: psutil>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from apache-airflow) (5.9.4)
# Collecting argcomplete>=1.10
#   Downloading argcomplete-3.0.3-py3-none-any.whl (39 kB)
# Collecting pathspec~=0.9.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting pendulum>=2.0
#   Downloading pendulum-2.1.2-cp39-cp39-manylinux1_x86_64.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 KB 21.3 MB/s eta 0:00:00
# Collecting apache-airflow-providers-common-sql
#   Downloading apache_airflow_providers_common_sql-1.3.4-py3-none-any.whl (31 kB)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from apache-airflow) (2.2.0)
# Requirement already satisfied: pygments>=2.0.1 in /usr/local/lib/python3.9/dist-packages (from apache-airflow) (2.6.1)
# Requirement already satisfied: markupsafe>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from apache-airflow) (2.1.2)
# Collecting rfc3339-validator>=0.1.4
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Requirement already satisfied: jsonschema>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from apache-airflow) (4.3.3)
# Collecting flask-appbuilder==4.1.4
#   Downloading Flask_AppBuilder-4.1.4-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 77.7 MB/s eta 0:00:00
# Collecting cron-descriptor>=1.2.24
#   Downloading cron_descriptor-1.2.35.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-slugify>=5.0 in /usr/local/lib/python3.9/dist-packages (from apache-airflow) (8.0.1)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.9/dist-packages (from apache-airflow) (2.1.2)
# Requirement already satisfied: sqlalchemy<2.0,>=1.4 in /usr/local/lib/python3.9/dist-packages (from apache-airflow) (1.4.46)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from apache-airflow) (4.5.0)
# Collecting python-daemon>=3.0.0
#   Downloading python_daemon-3.0.1-py3-none-any.whl (31 kB)
# Collecting httpx
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 KB 10.9 MB/s eta 0:00:00
# Collecting blinker
#   Downloading blinker-1.5-py2.py3-none-any.whl (12 kB)
# Collecting dill>=0.2.2
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 16.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=14.0 in /usr/local/lib/python3.9/dist-packages (from apache-airflow) (23.0)
# Collecting linkify-it-py>=2.0.0
#   Downloading linkify_it_py-2.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: tabulate>=0.7.5 in /usr/local/lib/python3.9/dist-packages (from apache-airflow) (0.8.10)
# Collecting deprecated>=1.2.13
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting python-nvd3>=0.15.0
#   Downloading python-nvd3-0.15.0.tar.gz (31 kB)
#   Preparing metadata (setup.py) ... done
# Collecting colorlog<5.0,>=4.0.2
#   Downloading colorlog-4.8.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: graphviz>=0.12 in /usr/local/lib/python3.9/dist-packages (from apache-airflow) (0.20.1)
# Collecting markdown-it-py>=2.1.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: flask<2.3,>=2.2 in /usr/local/lib/python3.9/dist-packages (from apache-airflow) (2.2.3)
# Collecting setproctitle>=1.1.8
#   Downloading setproctitle-1.3.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting cattrs>=22.1.0
#   Downloading cattrs-22.2.0-py3-none-any.whl (35 kB)
# Collecting sqlalchemy-jsonfield>=1.0
#   Downloading SQLAlchemy_JSONField-1.0.1.post0-py3-none-any.whl (10 kB)
# Collecting apache-airflow-providers-http
#   Downloading apache_airflow_providers_http-4.2.0-py3-none-any.whl (22 kB)
# Collecting cryptography>=0.9.3
#   Downloading cryptography-39.0.2-cp36-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 43.7 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=2.0 in /usr/local/lib/python3.9/dist-packages (from apache-airflow) (2.2.3)
# Collecting rich>=12.4.4
#   Downloading rich-13.3.2-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.7/238.7 KB 20.6 MB/s eta 0:00:00
# Collecting lockfile>=0.12.2
#   Downloading lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: attrs>=22.1.0 in /usr/local/lib/python3.9/dist-packages (from apache-airflow) (22.2.0)
# Collecting marshmallow-oneofschema>=2.0.1
#   Downloading marshmallow_oneofschema-3.0.1-py2.py3-none-any.whl (5.8 kB)
# Collecting apache-airflow-providers-ftp
#   Downloading apache_airflow_providers_ftp-3.3.1-py3-none-any.whl (19 kB)
# Collecting apache-airflow-providers-imap
#   Downloading apache_airflow_providers_imap-3.1.1-py3-none-any.whl (17 kB)
# Collecting flask-wtf>=0.15
#   Downloading Flask_WTF-1.1.1-py3-none-any.whl (12 kB)
# Collecting croniter>=0.3.17
#   Downloading croniter-1.3.8-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: jinja2>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from apache-airflow) (3.1.2)
# Collecting unicodecsv>=0.14.1
#   Downloading unicodecsv-0.14.1.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting lazy-object-proxy
#   Downloading lazy_object_proxy-1.9.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 KB 8.3 MB/s eta 0:00:00
# Collecting pyjwt>=2.0.0
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Collecting importlib-metadata<5.0.0,>=1.7
#   Downloading importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Collecting pluggy>=1.0
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Collecting configupdater>=3.1.1
#   Downloading ConfigUpdater-3.1.1-py2.py3-none-any.whl (34 kB)
# Collecting apache-airflow-providers-sqlite
#   Downloading apache_airflow_providers_sqlite-3.3.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: python-dateutil>=2.3 in /usr/local/lib/python3.9/dist-packages (from apache-airflow) (2.8.2)
# Collecting connexion[flask]>=2.10.0
#   Downloading connexion-2.14.2-py2.py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 KB 11.2 MB/s eta 0:00:00
# Collecting alembic<2.0,>=1.6.3
#   Downloading alembic-1.10.2-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 23.9 MB/s eta 0:00:00
# Requirement already satisfied: markdown>=3.0 in /usr/local/lib/python3.9/dist-packages (from apache-airflow) (3.4.1)
# Collecting flask-caching>=1.5.0
#   Downloading Flask_Caching-2.0.2-py3-none-any.whl (28 kB)
# Collecting gunicorn>=20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 11.5 MB/s eta 0:00:00
# Collecting colorama<1,>=0.3.9
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting sqlalchemy-utils<1,>=0.32.21
#   Downloading SQLAlchemy_Utils-0.40.0-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 KB 13.0 MB/s eta 0:00:00
# Collecting Flask-Babel<3,>=1
#   Downloading Flask_Babel-2.0.0-py3-none-any.whl (9.3 kB)
# Collecting marshmallow<4,>=3
#   Downloading marshmallow-3.19.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 KB 8.5 MB/s eta 0:00:00
# Collecting email-validator<2,>=1.0.5
#   Downloading email_validator-1.3.1-py2.py3-none-any.whl (22 kB)
# Collecting Flask-SQLAlchemy<3,>=2.4
#   Downloading Flask_SQLAlchemy-2.5.1-py2.py3-none-any.whl (17 kB)
# Collecting marshmallow-sqlalchemy<0.27.0,>=0.22.0
#   Downloading marshmallow_sqlalchemy-0.26.1-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: click<9,>=8 in /usr/local/lib/python3.9/dist-packages (from flask-appbuilder==4.1.4->apache-airflow) (8.1.3)
# Collecting prison<1.0.0,>=0.2.1
#   Downloading prison-0.2.1-py2.py3-none-any.whl (5.8 kB)
# Collecting marshmallow-enum<2,>=1.5.1
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting apispec[yaml]<4,>=3.3
#   Downloading apispec-3.3.2-py2.py3-none-any.whl (27 kB)
# Collecting WTForms<4
#   Downloading WTForms-3.0.1-py3-none-any.whl (136 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.5/136.5 KB 21.0 MB/s eta 0:00:00
# Collecting Flask-JWT-Extended<5.0.0,>=4.0.0
#   Downloading Flask_JWT_Extended-4.4.4-py2.py3-none-any.whl (22 kB)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 KB 14.3 MB/s eta 0:00:00
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.1.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: requests<3,>=2.9.1 in /usr/local/lib/python3.9/dist-packages (from connexion[flask]>=2.10.0->apache-airflow) (2.27.1)
# Requirement already satisfied: PyYAML<7,>=5.1 in /usr/local/lib/python3.9/dist-packages (from connexion[flask]>=2.10.0->apache-airflow) (6.0)
# Collecting inflection<0.6,>=0.3.1
#   Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Collecting clickclick<21,>=1.2
#   Downloading clickclick-20.10.2-py2.py3-none-any.whl (7.4 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=0.9.3->apache-airflow) (1.15.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/dist-packages (from deprecated>=1.2.13->apache-airflow) (1.15.0)
# Collecting cachelib<0.10.0,>=0.9.0
#   Downloading cachelib-0.9.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: setuptools>=3.0 in /usr/local/lib/python3.9/dist-packages (from gunicorn>=20.1.0->apache-airflow) (63.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata<5.0.0,>=1.7->apache-airflow) (3.15.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=4.0.0->apache-airflow) (0.19.3)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting pytzdata>=2020.1
#   Downloading pytzdata-2020.1-py2.py3-none-any.whl (489 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.0/490.0 KB 47.1 MB/s eta 0:00:00
# Requirement already satisfied: docutils in /usr/local/lib/python3.9/dist-packages (from python-daemon>=3.0.0->apache-airflow) (0.16)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.3->apache-airflow) (1.15.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.9/dist-packages (from python-slugify>=5.0->apache-airflow) (1.3)
# Collecting pygments>=2.0.1
#   Downloading Pygments-2.14.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 68.8 MB/s eta 0:00:00
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy<2.0,>=1.4->apache-airflow) (2.0.2)
# Requirement already satisfied: sqlparse>=0.4.2 in /usr/local/lib/python3.9/dist-packages (from apache-airflow-providers-common-sql->apache-airflow) (0.4.3)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 64.9 MB/s eta 0:00:00
# Collecting requests-toolbelt
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 9.2 MB/s eta 0:00:00
# Collecting asgiref
#   Downloading asgiref-3.6.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from httpx->apache-airflow) (2022.12.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.9/dist-packages (from httpx->apache-airflow) (1.3.0)
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 KB 12.0 MB/s eta 0:00:00
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=0.9.3->apache-airflow) (2.21)
# Collecting dnspython>=1.15.0
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 KB 34.3 MB/s eta 0:00:00
# Requirement already satisfied: idna>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from email-validator<2,>=1.0.5->flask-appbuilder==4.1.4->apache-airflow) (3.4)
# Requirement already satisfied: Babel>=2.3 in /usr/local/lib/python3.9/dist-packages (from Flask-Babel<3,>=1->flask-appbuilder==4.1.4->apache-airflow) (2.12.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.9/dist-packages (from Flask-Babel<3,>=1->flask-appbuilder==4.1.4->apache-airflow) (2022.7.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.9/dist-packages (from httpcore<0.17.0,>=0.15.0->httpx->apache-airflow) (3.6.2)
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.9.1->connexion[flask]>=2.10.0->apache-airflow) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.9.1->connexion[flask]>=2.10.0->apache-airflow) (2.0.12)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 36.5 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 25.4 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 18.2 MB/s eta 0:00:00
# Building wheels for collected packages: cron-descriptor, python-nvd3, unicodecsv
#   Building wheel for cron-descriptor (setup.py) ... done
#   Created wheel for cron-descriptor: filename=cron_descriptor-1.2.35-py3-none-any.whl size=48440 sha256=37ffcaf7fb4d774d78690158309a1bdc41ccb74b9d3c50b0b3de15e89e173364
#   Stored in directory: /root/.cache/pip/wheels/b6/c5/95/ecfd3eb95909eadd47c5ad25c8815c348d07bc248e12d3fd97
#   Building wheel for python-nvd3 (setup.py) ... done
#   Created wheel for python-nvd3: filename=python_nvd3-0.15.0-py3-none-any.whl size=38163 sha256=c749ec713ee1cfd0240e490e57445e91517ec889488ef45c40a0aaf09eb4e7b5
#   Stored in directory: /root/.cache/pip/wheels/60/e8/21/19a3dcfe90e8895952857d42152663fafc5a90d87d3dfe5f58
#   Building wheel for unicodecsv (setup.py) ... done
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10766 sha256=440d1f71d5f241a3737128f10fcf9616a2e483a74f3c9e77fe9b72409290cf28
#   Stored in directory: /root/.cache/pip/wheels/d8/c8/27/b237d3378d5c9ed25c2c63d9af1b3d5ccb99934f3dd030de87
# Successfully built cron-descriptor python-nvd3 unicodecsv
# Installing collected packages: unicodecsv, rfc3986, lockfile, cron-descriptor, colorlog, WTForms, uc-micro-py, setproctitle, rfc3339-validator, pytzdata, python-daemon, pyjwt, pygments, prison, pluggy, pathspec, multidict, mdurl, marshmallow, Mako, lazy-object-proxy, inflection, importlib-metadata, h11, gunicorn, frozenlist, exceptiongroup, dnspython, dill, deprecated, configupdater, colorama, clickclick, cachelib, blinker, async-timeout, asgiref, argcomplete, apispec, apache-airflow-providers-imap, apache-airflow-providers-ftp, apache-airflow-providers-common-sql, yarl, sqlalchemy-utils, sqlalchemy-jsonfield, requests-toolbelt, python-nvd3, pendulum, marshmallow-sqlalchemy, marshmallow-oneofschema, marshmallow-enum, markdown-it-py, linkify-it-py, httpcore, email-validator, cryptography, croniter, cattrs, apache-airflow-providers-sqlite, alembic, aiosignal, rich, mdit-py-plugins, httpx, flask-wtf, Flask-SQLAlchemy, flask-session, flask-login, Flask-JWT-Extended, flask-caching, Flask-Babel, connexion, aiohttp, flask-appbuilder, apache-airflow-providers-http, apache-airflow
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.6.1
#     Uninstalling Pygments-2.6.1:
#       Successfully uninstalled Pygments-2.6.1
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.0.0
#     Uninstalling importlib-metadata-6.0.0:
#       Successfully uninstalled importlib-metadata-6.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# pytest 3.6.4 requires pluggy<0.8,>=0.5, but you have pluggy 1.0.0 which is incompatible.
# Successfully installed Flask-Babel-2.0.0 Flask-JWT-Extended-4.4.4 Flask-SQLAlchemy-2.5.1 Mako-1.2.4 WTForms-3.0.1 aiohttp-3.8.4 aiosignal-1.3.1 alembic-1.10.2 apache-airflow-2.5.2 apache-airflow-providers-common-sql-1.3.4 apache-airflow-providers-ftp-3.3.1 apache-airflow-providers-http-4.2.0 apache-airflow-providers-imap-3.1.1 apache-airflow-providers-sqlite-3.3.1 apispec-3.3.2 argcomplete-3.0.3 asgiref-3.6.0 async-timeout-4.0.2 blinker-1.5 cachelib-0.9.0 cattrs-22.2.0 clickclick-20.10.2 colorama-0.4.6 colorlog-4.8.0 configupdater-3.1.1 connexion-2.14.2 cron-descriptor-1.2.35 croniter-1.3.8 cryptography-39.0.2 deprecated-1.2.13 dill-0.3.6 dnspython-2.3.0 email-validator-1.3.1 exceptiongroup-1.1.1 flask-appbuilder-4.1.4 flask-caching-2.0.2 flask-login-0.6.2 flask-session-0.4.0 flask-wtf-1.1.1 frozenlist-1.3.3 gunicorn-20.1.0 h11-0.14.0 httpcore-0.16.3 httpx-0.23.3 importlib-metadata-4.13.0 inflection-0.5.1 lazy-object-proxy-1.9.0 linkify-it-py-2.0.0 lockfile-0.12.2 markdown-it-py-2.2.0 marshmallow-3.19.0 marshmallow-enum-1.5.1 marshmallow-oneofschema-3.0.1 marshmallow-sqlalchemy-0.26.1 mdit-py-plugins-0.3.5 mdurl-0.1.2 multidict-6.0.4 pathspec-0.9.0 pendulum-2.1.2 pluggy-1.0.0 prison-0.2.1 pygments-2.14.0 pyjwt-2.6.0 python-daemon-3.0.1 python-nvd3-0.15.0 pytzdata-2020.1 requests-toolbelt-0.10.1 rfc3339-validator-0.1.4 rfc3986-1.5.0 rich-13.3.2 setproctitle-1.3.2 sqlalchemy-jsonfield-1.0.1.post0 sqlalchemy-utils-0.40.0 uc-micro-py-1.0.1 unicodecsv-0.14.1 yarl-1.8.2

# %%
default_args = {
    'owner': 'telecom',
    'depends_on_past': False,
    'start_date': datetime(2022, 2, 18),
    'email': ['someda@gmail.com'],
    'email_on_failure': True,
    'email_on_retry': False,
    'retries': 3,
    'retry_delay': timedelta(minutes=5)
}

# %% [markdown]
# run 'crontab -e'
#
# 0 0 * * 7 /path/to/this/pipelinescript.py

# %% [markdown]
# ● **Test the pipeline**: Test the data pipeline to ensure it produces the correct results. This
# can be done by comparing the results with the expected output or using a test dataset.
#
# ● **Optimize the pipeline**: Optimize the data pipeline to improve performance and reduce
# errors. This can be done by optimizing the code, parallel processing, and reducing the
# data size.
#
# ● **Monitor the pipeline:** Monitor the data pipeline to ensure that it runs smoothly and that
# there are no errors or issues.
